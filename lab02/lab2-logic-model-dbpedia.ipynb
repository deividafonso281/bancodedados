# %% [markdown]
# # Laboratório 2

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

url_tent = "https://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"

data_tent = requests.get(url_tent)
json_tent = data_tent.json()

print(json.dumps(json_tent, indent=4))
# Out:
# {
#     "d": {
#         "results": [
#             {
#                 "__metadata": {
#                     "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#                 },
#                 "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#                 "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/resource/French_New_Wave"
#                     }
#                 },
#                 "http://purl.org/dc/terms/subject": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                     }
#                 },
#                 "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/ontology/WrittenWork"
#                     }
#                 },
#                 "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                     }
#                 },
#                 "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#                 "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#                 "http://dbpedia.org/property/pubDate": "1969",
#                 "http://dbpedia.org/property/country": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/resource/Brazil"
#                     }
#                 },
#                 "http://www.w3.org/2002/07/owl#sameAs": {
#                     "__deferred": {
#                         "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                     }
#                 },
#                 "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#                 "http://dbpedia.org/property/author": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                     }
#                 },
#                 "http://dbpedia.org/ontology/author": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                     }
#                 },
#                 "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#                 "http://dbpedia.org/property/englishPubDate": "1971",
#                 "http://dbpedia.org/ontology/country": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/resource/Brazil"
#                     }
#                 },
#                 "http://dbpedia.org/property/name": "Tent of Miracles",
#                 "http://purl.org/linguistics/gold/hypernym": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/resource/Novel"
#                     }
#                 },
#                 "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#                 "http://dbpedia.org/ontology/publisher": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/resource/Brazil"
#                     }
#                 },
#                 "http://dbpedia.org/ontology/language": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/resource/Portuguese_language"
#                     }
#                 },
#                 "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                     "__deferred": {
#                         "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                     }
#                 },
#                 "http://dbpedia.org/ontology/wikiPageLength": "5253",
#                 "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#                 "http://dbpedia.org/property/language": {
#                     "__deferred": {
#                         "uri": "http://dbpedia.org/resource/Portuguese_language"
#                     }
#                 },
#                 "http://dbpedia.org/ontology/wikiPageID": "623351",
#                 "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#                 "http://dbpedia.org/property/caption": "First edition",
#                 "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                     "__deferred": {
#                         "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                     }
#                 }
#             }
#         ],
#         "__count": "1"
#     }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
import json
import requests

url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = "Tent of Miracles (novel)"
format = "jsod"

concept = concept.replace(" ","_")

url = url_template.replace("{concept}",concept)\
            .replace("{format}",format)

data = requests.get(url)
js = data.json()
print(js["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"])
# Out:
# http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
import json
import requests

url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()

uri_mesh = json_mi[0]["resource"]
bar = str.rindex(uri_mesh, "/")
url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid, indent=3))
# Out:
# {
#    "descriptor": "http://id.nlm.nih.gov/mesh/D001241",
#    "terms": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003713",
#          "label": "Aspirin",
#          "preferred": true
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003714",
#          "label": "2-(Acetyloxy)benzoic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003712",
#          "label": "Acetylsalicylic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003721",
#          "label": "Acetysal",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003722",
#          "label": "Acylpyrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003711",
#          "label": "Aloxiprimum",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003723",
#          "label": "Colfarit",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003715",
#          "label": "Dispril",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003719",
#          "label": "Easprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003724",
#          "label": "Ecotrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003725",
#          "label": "Endosprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003726",
#          "label": "Magnecyl",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003727",
#          "label": "Micristin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003717",
#          "label": "Polopirin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003728",
#          "label": "Polopiryna",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003716",
#          "label": "Solprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003718",
#          "label": "Solupsan",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003720",
#          "label": "Zorprin",
#          "preferred": false
#       }
#    ],
#    "qualifiers": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000008",
#          "label": "administration & dosage"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000009",
#          "label": "adverse effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000819",
#          "label": "agonists"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000031",
#          "label": "analogs & derivatives"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000032",
#          "label": "analysis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000037",
#          "label": "antagonists & inhibitors"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000097",
#          "label": "blood"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000134",
#          "label": "cerebrospinal fluid"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000138",
#          "label": "chemical synthesis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000737",
#          "label": "chemistry"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000145",
#          "label": "classification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000191",
#          "label": "economics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000266",
#          "label": "history"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000276",
#          "label": "immunology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000302",
#          "label": "isolation & purification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000378",
#          "label": "metabolism"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000493",
#          "label": "pharmacokinetics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000494",
#          "label": "pharmacology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000506",
#          "label": "poisoning"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000528",
#          "label": "radiation effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000592",
#          "label": "standards"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000600",
#          "label": "supply & distribution"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000627",
#          "label": "therapeutic use"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000633",
#          "label": "toxicity"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000652",
#          "label": "urine"
#       }
#    ],
#    "seealso": []
# }

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
import requests
import json

url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Wall Street"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
money_ref = data.json()
print(json.dumps(money_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 191044549,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 447018423,
#       "boundingbox": [
#          "40.7051753",
#          "40.706379",
#          "-74.009502",
#          "-74.0074038"
#       ],
#       "lat": "40.7060194",
#       "lon": "-74.0088308",
#       "display_name": "Wall Street, Financial District, Manhattan, New York County, New York, 10005, United States",
#       "class": "highway",
#       "type": "residential",
#       "importance": 0.758852318921325
#    },
#    {
#       "place_id": 84961970,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 5672361,
#       "boundingbox": [
#          "40.7074957",
#          "40.7077608",
#          "-74.0116831",
#          "-74.011267"
#       ],
#       "lat": "40.7077234",
#       "lon": "-74.0116244",
#       "display_name": "Wall Street, Financial District, Manhattan, New York County, New York, 10005, United States",
#       "class": "highway",
#       "type": "pedestrian",
#       "importance": 0.758852318921325
#    },
#    {
#       "place_id": 5562036,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 597928300,
#       "boundingbox": [
#          "40.7017241",
#          "40.7117241",
#          "-74.0141832",
#          "-74.0041832"
#       ],
#       "lat": "40.7067241",
#       "lon": "-74.0091832",
#       "display_name": "Wall Street, William Street, Manhattan Community Board 1, Manhattan, New York County, New York, 10038, United States",
#       "class": "railway",
#       "type": "station",
#       "importance": 0.5703375739998475,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//transport_train_station2.p.20.png"
#    },
#    {
#       "place_id": 60264412,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 5367519866,
#       "boundingbox": [
#          "40.7029284",
#          "40.7129284",
#          "-74.0164693",
#          "-74.0064693"
#       ],
#       "lat": "40.7079284",
#       "lon": "-74.0114693",
#       "display_name": "Wall Street, Broadway, Manhattan Community Board 1, Manhattan, New York County, New York, 10003, United States",
#       "class": "railway",
#       "type": "station",
#       "importance": 0.5701859567047569,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//transport_train_station2.p.20.png"
#    },
#    {
#       "place_id": 363896,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 151413908,
#       "boundingbox": [
#          "37.5925414",
#          "37.6325414",
#          "-92.9749046",
#          "-92.9349046"
#       ],
#       "lat": "37.6125414",
#       "lon": "-92.9549046",
#       "display_name": "Wall Street, Dallas County, Missouri, 65590, United States",
#       "class": "place",
#       "type": "hamlet",
#       "importance": 0.45,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 186156248,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 421125311,
#       "boundingbox": [
#          "38.54105",
#          "38.5699016",
#          "-109.6053406",
#          "-109.5842909"
#       ],
#       "lat": "38.5551635",
#       "lon": "-109.5934959",
#       "display_name": "Wall Street, Grand County, Utah, 84532-2134, United States",
#       "class": "natural",
#       "type": "cliff",
#       "importance": 0.39999999999999997
#    },
#    {
#       "place_id": 316818319,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 942773771,
#       "boundingbox": [
#          "40.3926147",
#          "40.3926861",
#          "-79.8045537",
#          "-79.8038746"
#       ],
#       "lat": "40.392682",
#       "lon": "-79.8042926",
#       "display_name": "Wall Street, Wall, Allegheny County, Pennsylvania, 15148, United States",
#       "class": "highway",
#       "type": "residential",
#       "importance": 0.31
#    },
#    {
#       "place_id": 94324080,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 22719814,
#       "boundingbox": [
#          "54.0864213",
#          "54.0864894",
#          "12.1360601",
#          "12.1392492"
#       ],
#       "lat": "54.0864469",
#       "lon": "12.1372992",
#       "display_name": "Wallstra\u00dfe, N\u00f6rdliche Altstadt, Stadtmitte, Ortsbeirat 14 : Stadtmitte, Rostock, Mecklenburg-Vorpommern, 18055, Deutschland",
#       "class": "highway",
#       "type": "residential",
#       "importance": 0.28764122278025944
#    },
#    {
#       "place_id": 84588707,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 4926385,
#       "boundingbox": [
#          "53.8584226",
#          "53.8584358",
#          "10.6852022",
#          "10.6854629"
#       ],
#       "lat": "53.8584358",
#       "lon": "10.6854629",
#       "display_name": "Wallstra\u00dfe, Innenstadt, L\u00fcbeck, Schleswig-Holstein, 23552, Deutschland",
#       "class": "highway",
#       "type": "secondary",
#       "importance": 0.253150759043076
#    },
#    {
#       "place_id": 98638304,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 33121094,
#       "boundingbox": [
#          "51.8639379",
#          "51.8642548",
#          "12.6496332",
#          "12.6516587"
#       ],
#       "lat": "51.864066",
#       "lon": "12.6508252",
#       "display_name": "Wallstra\u00dfe, Altstadt, Wittenberg, Sachsen-Anhalt, 06886, Deutschland",
#       "class": "highway",
#       "type": "residential",
#       "importance": 0.19999999999999998
#    }
# ]

# %%
print(money_ref[0]["osm_id"])
# Out:
# 447018423

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(money_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
money_way = data.json()
print(json.dumps(money_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (956768 spike-06.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 447018423,
#          "timestamp": "2021-08-22T14:36:13Z",
#          "version": 13,
#          "changeset": 110064266,
#          "user": "jmapb",
#          "uid": 4400159,
#          "nodes": [
#             42448578,
#             7097820971,
#             2824895141,
#             8276468666,
#             42444414,
#             7139624476,
#             7139624399,
#             42453902
#          ],
#          "tags": {
#             "access": "yes",
#             "highway": "residential",
#             "lit": "yes",
#             "maxspeed": "25 mph",
#             "name": "Wall Street",
#             "name:en": "Wall Street",
#             "name:ja": "\u30a6\u30a9\u30fc\u30eb\u30b9\u30c8\u30ea\u30fc\u30c8",
#             "name:ru": "\u0423\u043e\u043b\u043b \u0441\u0442\u0440\u0438\u0442",
#             "name:zh": "\u534e\u5c14\u8857",
#             "oneway": "yes",
#             "sidewalk": "both",
#             "surface": "asphalt",
#             "tiger:cfcc": "A41",
#             "tiger:county": "New York, NY",
#             "tiger:name_base": "Wall",
#             "tiger:name_type": "St",
#             "tiger:reviewed": "no",
#             "tiger:zip_left": "10005",
#             "tiger:zip_right": "10005",
#             "wikidata": "Q11690",
#             "wikipedia": "en:Wall Street"
#          }
#       }
#    ]
# }

# %%
print(money_way["elements"][0]["tags"]["wikipedia"])
# Out:
# en:Wall Street

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = money_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
money_dbpedia = data.json()
print(json.dumps(money_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Wall_Street"
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://sv.dbpedia.org/resource/Wall_Street"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/WikicatStreetsInNewYorkCity"
#                }
#             },
#             "http://dbpedia.org/ontology/abstract": "Wall Street is een straat in Lower Manhattan, het zuidelijkste gedeelte van het eiland Manhattan, dat het hart van New York vormt. Wall Street wordt vaak gebruikt als metonymie voor de Amerikaanse financi\u00eble wereld.",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Federal_Hall"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Wikiquote"
#                }
#             },
#             "http://dbpedia.org/property/name": "Wall Street",
#             "http://www.w3.org/2000/01/rdf-schema#label": "\u30a6\u30a9\u30fc\u30eb\u8857",
#             "http://dbpedia.org/property/directionB": "East",
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Is sr\u00e1id ch\u00fang i Manhattan \u00edochtarach, i gcathair Nua Eabhraic, \u00ed Wall Street. T\u00e1 an tionscail airgeadais agus infheist\u00edochta i St\u00e1it Aontaithe Mheirice\u00e1 lonnaithe ar Wall Street agus sna sr\u00e1ideanna m\u00f3rthimpeall.",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Wall_Street?oldid=1024820695&ns=0"
#                }
#             },
#             "http://dbpedia.org/property/terminusA": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Broadway_(Manhattan)"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "81944",
#             "http://dbpedia.org/ontology/routeEnd": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/South_Street_(Manhattan)"
#                }
#             },
#             "http://dbpedia.org/property/terminusB": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/South_Street_(Manhattan)"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "https://archive.org/details/mastersofcapitaljohn00moodiala"
#                }
#             },
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/255879045"
#                }
#             },
#             "http://dbpedia.org/property/imageSize": "320",
#             "http://dbpedia.org/ontology/wikiPageID": "37274",
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Forts_of_New_Netherland"
#                }
#             },
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Street"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1024820695",
#             "http://dbpedia.org/ontology/routeStartDirection": "West",
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Wall_Street_map2.svg?width=300"
#                }
#             },
#             "http://www.w3.org/2004/02/skos/core#exactMatch": {
#                "__deferred": {
#                   "uri": "http://globalwordnet.org/ili/i84570"
#                }
#             },
#             "http://dbpedia.org/property/caption": "The New York Stock Exchange Building&#39;s Broad Street entrance  as seen from Wall Street",
#             "http://dbpedia.org/ontology/routeStart": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Broadway_(Manhattan)"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Wall_Street"
#                }
#             },
#             "http://dbpedia.org/ontology/routeEndDirection": "East",
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Wall_Street_map2.svg"
#                }
#             },
#             "http://dbpedia.org/property/mapSize": "320",
#             "http://xmlns.com/foaf/0.1/name": "Wall Street",
#             "http://dbpedia.org/property/directionA": "West",
#             "http://dbpedia.org/property/imageMap": "Wall Street map2.svg"
#          }
#       ],
#       "__count": "1"
#    }
# }
